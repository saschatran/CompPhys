# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
dfSArr = pd.read_csv("sumArr.csv")
dfSMat = pd.read_csv("sumMat.csv")

# %%
df = dfSArr
df["Matrix Time"] = dfSMat["Matrix Time"]

indices = df.loc[df["Size of array"] == " ---"].index

dfSAll = []

pre = 0
for index in indices:
    dfSAll.append(df.iloc[pre:index])
    pre = index + 1

dfSAll[5]
# Out:
#      Size of array  Array Time  Matrix Time
# 5005        100001    0.000286     0.000354
# 5006        100002    0.000571     0.000355
# 5007        100003    0.000713     0.000356
# 5008        100004    0.000982     0.000357
# 5009        100005    0.001123     0.000358
# ...            ...         ...          ...
# 6000        100996    0.145521     0.001361
# 6001        100997    0.145667     0.001362
# 6002        100998    0.145814     0.001363
# 6003        100999    0.145958     0.001363
# 6004        101000    0.146132     0.001364
#
# [1000 rows x 3 columns]

# %%
from matplotlib import ticker
def plotLine(data, counter):
    plt.clf()
    
    d = data[counter]
    ax = d.plot(x='Size of array', y='Matrix Time')
    ax = d.plot(x='Size of array', y='Array Time', ax=ax)

    init = int(data[counter]["Size of array"].iloc[0]) - 1
    
    ax.yaxis.set_major_formatter(plt.ScalarFormatter())
    ax.ticklabel_format(style='sci', axis='y', scilimits=(0,0))

    ax.xaxis.set_major_locator(ticker.MultipleLocator(100))

    
    plt.xticks(rotation=45)
    plt.legend(loc='upper left')

    plt.savefig(f"len{init}.png")

# %%
plotLine(dfSAll, 0)

# %%
plotLine(dfSAll, 1)

# %%
plotLine(dfSAll, 2)

# %%
plotLine(dfSAll, 3)

# %%
plotLine(dfSAll, 4)

# %%
plotLine(dfSAll, 5)

# %%
print("Init size of array", "Array Time", "Matrix Time")
for df in dfSAll:
    print(df.iloc[0]["Size of array"], df.iloc[-1]["Array Time"], df.iloc[-1]["Matrix Time"])
# Out:
# Init size of array Array Time Matrix Time
# 2 0.001274 0.000935
# 11 0.001339 0.000599
# 101 0.001426 0.000479
# 1001 0.003122 0.000771
# 10001 0.0167 0.000955
# 100001 0.146132 0.001364
