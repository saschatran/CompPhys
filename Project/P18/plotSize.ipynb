# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dfSArr = pd.read_csv("sumArr.csv")
dfSMat = pd.read_csv("sumMat.csv")

# %%
df = dfSArr
df["Matrix Time"] = dfSMat["Matrix Time"]

indices = df.loc[df["Size of array"] == " ---"].index

dfSAll = []
pre = 0
for index in indices:
    dfSAll.append(df.iloc[pre:index])
    pre = index + 1

# %%
dfSAll[0].plot.line()
# Out:
# <Axes: >

# %%
dfSAll[1].plot.line()
# Out:
# <Axes: >

# %%
dfSAll[2].plot.line()
# Out:
# <Axes: >

# %%
dfSAll[3].plot.line()
# Out:
# <Axes: >

# %%
dfSAll[4].plot.line()
# Out:
# <Axes: >

# %%
print("Init size of array", "Array Time", "Matrix Time")
for df in dfSAll:
    print(df.iloc[0]["Size of array"], df.iloc[-1]["Array Time"], df.iloc[-1]["Matrix Time"])
# Out:
# Init size of array Array Time Matrix Time
# 11 0.001102 0.00039
# 101 0.001042 0.000406
# 1001 0.002373 0.000557
# 10001 0.010829 0.000444
# 100001 0.10182 0.000914
